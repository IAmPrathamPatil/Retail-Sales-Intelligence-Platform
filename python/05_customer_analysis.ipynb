# %%
# # Executive Summary

# ## Key Findings

# - Customer distribution is concentrated in a limited number of states.
# - São Paulo contributes the largest customer base.
# - Revenue strongly correlates with customer concentration.
# - Monthly customer acquisition varies over time.
# - Average customer spending provides opportunities for upselling.

# ## Recommendations

# - Expand customer acquisition in underrepresented regions.
# - Improve customer retention through loyalty programs.
# - Increase marketing investment in high-value cities.
# - Personalize offers to improve customer lifetime value.

# %%
fig=px.bar(

monthly,

x="month",

y="Growth %",

text_auto=".2f",

title="Customer Growth"

)

fig.update_layout(

template="plotly_white",

title_x=0.5

)

fig.show()

# %%
monthly["Growth %"]=monthly["customer_id"].pct_change()*100

monthly
# Out:
#       month  customer_id      Growth %
# 0   2016-09            3           NaN
# 1   2016-10          324  10700.000000
# 2   2016-12            1    -99.691358
# 3   2017-01          800  79900.000000
# 4   2017-02         1780    122.500000
# 5   2017-03         2682     50.674157
# 6   2017-04         2404    -10.365399
# 7   2017-05         3700     53.910150
# 8   2017-06         3245    -12.297297
# 9   2017-07         4026     24.067797
# 10  2017-08         4331      7.575758
# 11  2017-09         4285     -1.062110
# 12  2017-10         4631      8.074679
# 13  2017-11         7544     62.902181
# 14  2017-12         5673    -24.801166
# 15  2018-01         7269     28.133263
# 16  2018-02         6728     -7.442564
# 17  2018-03         7211      7.178954
# 18  2018-04         6939     -3.772015
# 19  2018-05         6873     -0.951146
# 20  2018-06         6167    -10.272079
# 21  2018-07         6292      2.026917
# 22  2018-08         6512      3.496503
# ...

# %%
fig=px.line(

monthly,

x="month",

y="customer_id",

markers=True,

title="Monthly Customers"

)

fig.update_layout(

template="plotly_white",

title_x=0.5

)

fig.show()

# %%
monthly=(

customers.groupby(

"month"

)["customer_id"]

.nunique()

.reset_index()

)

monthly["month"]=monthly["month"].astype(str)

monthly.head()
# Out:
#      month  customer_id
# 0  2016-09            3
# 1  2016-10          324
# 2  2016-12            1
# 3  2017-01          800
# 4  2017-02         1780

# %%
customers["month"]=customers[

"order_purchase_timestamp"

].dt.to_period("M")

# %%
avg=(

customers.groupby(

"customer_id"

)["payment_value"]

.sum()

.mean()

)

print(avg)
# Out:
# 160.9902666934835

# %%
fig=px.bar(

revenue,

x="customer_state",

y="payment_value",

title="Revenue by State",

text_auto=".2s"

)

fig.update_layout(

template="plotly_white",

title_x=0.5

)

fig.show()

# %%
revenue=(

customers.groupby("customer_state")["payment_value"]

.sum()

.sort_values(ascending=False)

.reset_index()

)

revenue.head()
# Out:
#   customer_state  payment_value
# 0             SP     5998226.96
# 1             RJ     2144379.69
# 2             MG     1872257.26
# 3             RS      890898.54
# 4             PR      811156.38

# %%
fig=px.bar(

city,

x="customer_city",

y="customer_id",

title="Top 10 Customer Cities",

text_auto=True

)

fig.update_layout(

template="plotly_white",

title_x=0.5

)

fig.show()

# %%
city = (
    customers.groupby("customer_city")["customer_id"]
    .nunique()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

city
# Out:
#            customer_city  customer_id
# 0              sao paulo        15540
# 1         rio de janeiro         6882
# 2         belo horizonte         2773
# 3               brasilia         2131
# 4               curitiba         1521
# 5               campinas         1444
# 6           porto alegre         1379
# 7               salvador         1245
# 8              guarulhos         1189
# 9  sao bernardo do campo          938

# %%
# ## Business Insight

# Customer concentration is significantly higher in a few states.

# These regions represent the strongest customer base.

# ## Recommendation

# Increase customer loyalty programs in these regions while
# expanding acquisition campaigns in low-performing states.

# %%
fig=px.bar(

state_customers,

x="customer_state",

y="customer_id",

title="Customers by State",

text_auto=True

)

fig.update_layout(

template="plotly_white",

title_x=0.5

)

fig.show()

# %%
state_customers=(

customers.groupby("customer_state")["customer_id"]

.nunique()

.sort_values(ascending=False)

.reset_index()

)

state_customers.head()
# Out:
#   customer_state  customer_id
# 0             SP        41745
# 1             RJ        12852
# 2             MG        11635
# 3             RS         5466
# 4             PR         5045

# %%
customers["customer_state"].nunique()
# Out:
# 27

# %%
customers["customer_city"].nunique()
# Out:
# 4119

# %%
customers["customer_id"].nunique()
# Out:
# 99440

# %%
customers["order_purchase_timestamp"]=pd.to_datetime(
customers["order_purchase_timestamp"]
)

# %%
customers=pd.read_sql("""

SELECT

c.customer_id,

c.customer_city,

c.customer_state,

o.order_id,

o.order_purchase_timestamp,

op.payment_value

FROM customers c

JOIN orders o

ON c.customer_id=o.customer_id

JOIN order_payments op

ON o.order_id=op.order_id

""",engine)

# %%
USERNAME="postgres"
PASSWORD="password"

HOST="localhost"
PORT="5432"
DATABASE="olist_retail"

engine=create_engine(
f"postgresql+psycopg2://{USERNAME}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}"
)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import plotly.express as px

from sqlalchemy import create_engine

# %%
# Customer Analysis

# ## Business Objective

# Customers are the foundation of every e-commerce business.

# This notebook analyzes customer behavior, geographic distribution,
# purchase patterns, and business opportunities.

# The objectives are:

# - Understand customer distribution
# - Identify top-performing states
# - Analyze customer cities
# - Measure customer purchasing behavior
# - Generate actionable business insights
