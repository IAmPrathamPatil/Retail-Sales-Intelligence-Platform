# %%
# Executive Summary

## Key Findings

# - Total revenue reached significant levels across the analyzed period.
# - Monthly revenue shows clear seasonal fluctuations.
# - A limited number of product categories generate the majority of revenue.
# - Credit cards remain the dominant payment method.
# - Revenue is concentrated in a few high-performing states.
# - Average order values indicate opportunities for upselling.

# ## Strategic Recommendations

# - Increase inventory before peak shopping periods.
# - Invest marketing budget in high-performing categories.
# - Expand sales initiatives in emerging regions.
# - Promote premium product bundles to increase average order value.
# - Optimize payment experience to improve conversion rates.

# This analysis serves as the foundation for executive dashboards
# and future customer, product, and seller analytics.

# %%
fig = px.bar(

avg_category.head(10),

x="product_category_name",

y="payment_value",

title="Average Revenue per Product Category",

text_auto=".2f"

)

fig.update_layout(

template="plotly_white",

title_x=0.5

)

fig.show()

# %%
avg_category = (

sales.groupby("product_category_name")["payment_value"]

.mean()

.sort_values(ascending=False)

.reset_index()

)

avg_category.head(10)
# Out:
#               product_category_name  payment_value
# 0                               pcs    1268.734318
# 1                    telefonia_fixa     763.875498
# 2       portateis_casa_forno_e_cafe     656.786154
# 3         agro_industria_e_comercio     471.153214
# 4                eletrodomesticos_2     464.789030
# 5                 moveis_escritorio     363.794426
# 6           sinalizacao_e_seguranca     340.736567
# 7  construcao_ferramentas_seguranca     330.105678
# 8             instrumentos_musicais     324.615766
# 9                   eletroportateis     321.803680

# %%
## Business Insight

# Customer payment preferences provide valuable information
# for optimizing checkout experiences and promotional offers.

# ## Recommendation

# Strengthen partnerships with the most popular payment
# providers and promote digital payment adoption.

# %%
fig = px.bar(

payment,

x="payment_type",

y="payment_value",

title="Revenue by Payment Method",

text_auto=".2s",

color="payment_type"

)

fig.update_layout(

template="plotly_white",

title_x=0.5

)

fig.show()

# %%
payment = (

sales.groupby("payment_type")["payment_value"]

.sum()

.sort_values(ascending=False)

.reset_index()

)

payment
# Out:
#   payment_type  payment_value
# 0  credit_card    15589028.22
# 1       boleto     4059699.60
# 2      voucher      405873.03
# 3   debit_card      253533.86

# %%
## Business Insight

# Certain states contribute significantly more revenue
# than others.

# These regions represent the company's strongest markets.

# ## Recommendation

# Focus marketing campaigns in high-performing states while
# developing growth strategies for underperforming regions.

# %%
fig = px.bar(

state_revenue,

x="customer_state",

y="payment_value",

title="Revenue by State",

text_auto=".2s"

)

fig.update_layout(

template="plotly_white",

title_x=0.5

)

fig.show()

# %%
state_revenue = (

sales.groupby("customer_state")["payment_value"]

.sum()

.sort_values(ascending=False)

.reset_index()

)

state_revenue.head()
# Out:
#   customer_state  payment_value
# 0             SP     7597209.66
# 1             RJ     2769347.44
# 2             MG     2326151.64
# 3             RS     1147277.00
# 4             PR     1064603.99

# %%
## Business Insight

# Revenue is concentrated among a few product categories.

# Diversifying sales across additional categories could reduce
# business dependency on a limited product portfolio.

# %%
fig = px.pie(

category_revenue.head(10),

values="Revenue %",

names="product_category_name",

title="Revenue Contribution by Top Categories"

)

fig.update_layout(

template="plotly_white",

title_x=0.5

)

fig.show()

# %%
category_revenue["Revenue %"] = (

category_revenue["payment_value"]

/

category_revenue["payment_value"].sum()

)*100

category_revenue.head()
# Out:
#     product_category_name  payment_value  Revenue %
# 0         cama_mesa_banho     1712553.67   8.539144
# 1            beleza_saude     1657373.12   8.264002
# 2  informatica_acessorios     1585330.45   7.904782
# 3        moveis_decoracao     1430176.39   7.131153
# 4      relogios_presentes     1429216.68   7.126367

# %%
## Business Insight

# A small number of product categories generate a large
# portion of total revenue.

# These categories represent the company's core business.

# ## Recommendation

# Increase advertising spend on high-performing categories
# and ensure inventory availability during peak demand.

# %%
fig = px.bar(

category_revenue.head(10),

x="product_category_name",

y="payment_value",

title="Top 10 Product Categories by Revenue",

text_auto=".2s"

)

fig.update_layout(

template="plotly_white",

title_x=0.5,

xaxis_title="Product Category",

yaxis_title="Revenue"

)

fig.show()

# %%
category_revenue = (

sales.groupby("product_category_name")["payment_value"]

.sum()

.sort_values(ascending=False)

.reset_index()

)

category_revenue.head(10)
# Out:
#     product_category_name  payment_value
# 0         cama_mesa_banho     1712553.67
# 1            beleza_saude     1657373.12
# 2  informatica_acessorios     1585330.45
# 3        moveis_decoracao     1430176.39
# 4      relogios_presentes     1429216.68
# 5           esporte_lazer     1392127.56
# 6   utilidades_domesticas     1094758.13
# 7              automotivo      852294.33
# 8      ferramentas_jardim      838280.75
# 9              cool_stuff      779698.00

# %%
## Business Insight

# Positive growth indicates expanding sales,
# while negative growth highlights periods requiring investigation.

# ## Recommendation

# Analyze months with declining growth to identify
# potential causes such as seasonality, competition,
# or reduced marketing activity.

# %%
fig = px.bar(

monthly_revenue,

x="month",

y="growth_%",

title="Monthly Revenue Growth (%)",

text_auto=".2f"

)

fig.update_layout(

template="plotly_white",

title_x=0.5

)

fig.show()

# %%
monthly_revenue["growth_%"] = (

monthly_revenue["payment_value"]

.pct_change()

*100

)

monthly_revenue
# Out:
#       month  payment_value       growth_%
# 0   2016-09         347.52            NaN
# 1   2016-10       73914.58   21169.158610
# 2   2016-12          19.62     -99.973456
# 3   2017-01      187779.41  956981.600408
# 4   2017-02      344134.79      83.265455
# 5   2017-03      526961.66      53.126529
# 6   2017-04      505665.53      -4.041305
# 7   2017-05      724504.55      43.277425
# 8   2017-06      600753.27     -17.080815
# 9   2017-07      737293.08      22.728101
# 10  2017-08      870105.90      18.013572
# 11  2017-09     1015849.57      16.750107
# 12  2017-10     1021169.27       0.523670
# 13  2017-11     1583869.01      55.103474
# 14  2017-12     1042855.86     -34.157695
# 15  2018-01     1408365.65      35.048927
# 16  2018-02     1306048.80      -7.264935
# 17  2018-03     1475599.95      12.981992
# 18  2018-04     1496811.52       1.437488
# 19  2018-05     1506974.84       0.678998
# 20  2018-06     1297594.81     -13.894063
# ...

# %%
## Business Insight

# Order volume reflects customer demand over time.

# Higher order counts often coincide with promotional campaigns
# or festive shopping periods.

# ## Recommendation

# Plan staffing and logistics around high-order months.

# %%
fig = px.bar(

monthly_orders,

x="month",

y="order_id",

title="Monthly Orders",

text_auto=True

)

fig.update_layout(

template="plotly_white",

title_x=0.5,

xaxis_title="Month",

yaxis_title="Orders"

)

fig.show()

# %%
monthly_orders = (

sales.groupby("month")["order_id"]

.nunique()

.reset_index()

)

monthly_orders["month"] = monthly_orders["month"].astype(str)

monthly_orders.head()
# Out:
#      month  order_id
# 0  2016-09         2
# 1  2016-10       308
# 2  2016-12         1
# 3  2017-01       789
# 4  2017-02      1733

# %%
## Business Insight

# - Revenue fluctuates across different months.
# - Peak sales indicate high customer demand.
# - Seasonal trends can influence inventory planning.

# ## Recommendation

# Increase marketing campaigns before peak months
# and optimize inventory to avoid stock shortages.

# %%
fig = px.line(

monthly_revenue,

x="month",

y="payment_value",

title="Monthly Revenue Trend",

markers=True

)

fig.update_layout(

template="plotly_white",

title_x=0.5,

xaxis_title="Month",

yaxis_title="Revenue"

)

fig.show()

# %%
monthly_revenue["month"] = monthly_revenue["month"].astype(str)

# %%
monthly_revenue = (

sales.groupby("month")["payment_value"]

.sum()

.reset_index()

)

monthly_revenue.head()
# Out:
#      month  payment_value
# 0  2016-09         347.52
# 1  2016-10       73914.58
# 2  2016-12          19.62
# 3  2017-01      187779.41
# 4  2017-02      344134.79

# %%
# Monthly Revenue Trend

Monthly revenue analysis helps identify seasonality,
growth patterns, and peak shopping periods.

This analysis supports inventory planning,
marketing strategy, and financial forecasting.

# %%
sales["customer_state"].nunique()
# Out:
# 27

# %%
sales["payment_value"].mean()
# Out:
# np.float64(172.68675189836821)

# %%
total_orders = sales["order_id"].nunique()

print(total_orders)
# Out:
# 98665

# %%
total_revenue = sales["payment_value"].sum()

print(f"Total Revenue : {total_revenue:,.2f}")
# Out:
# Total Revenue : 20,308,134.71

# %%
sales["month"] = sales["order_purchase_timestamp"].dt.to_period("M")

# %%
sales["order_purchase_timestamp"] = pd.to_datetime(
    sales["order_purchase_timestamp"]
)

# %%
sales = pd.read_sql("""

SELECT

o.order_id,
o.order_purchase_timestamp,

oi.product_id,

p.product_category_name,

op.payment_type,
op.payment_value,

c.customer_state

FROM orders o

JOIN customers c
ON o.customer_id = c.customer_id

JOIN order_items oi
ON o.order_id = oi.order_id

JOIN products p
ON oi.product_id = p.product_id

JOIN order_payments op
ON o.order_id = op.order_id

""", engine)

# %%
USERNAME = "postgres"
PASSWORD = "password"

HOST = "localhost"
PORT = "5432"
DATABASE = "olist_retail"

engine = create_engine(
    f"postgresql+psycopg2://{USERNAME}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}"
)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import plotly.express as px

from sqlalchemy import create_engine

# %%
# Sales Analysis

## Business Objective

The purpose of this notebook is to analyze the sales performance of the Brazilian e-commerce platform.

The analysis focuses on answering the following business questions:

- How much revenue has the company generated?
- Which months contribute the highest sales?
- Which product categories generate the highest revenue?
- Which payment methods are most preferred?
- Which states contribute the most revenue?
- What recommendations can improve sales performance?

This notebook forms the foundation of the Executive Business Intelligence Dashboard.
