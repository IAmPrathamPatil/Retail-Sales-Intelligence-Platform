# %%
# # Executive Visualization Summary

# ## Major Findings

# - Revenue demonstrates clear seasonal variation.
# - São Paulo remains the largest revenue contributor.
# - Credit Card dominates payment transactions.
# - A limited number of product categories generate the majority of revenue.
# - Customer ratings remain consistently positive.

# ## Recommendations

# - Increase inventory before peak demand periods.
# - Invest marketing resources in high-performing categories.
# - Expand into underperforming regions.
# - Encourage premium purchases through targeted promotions.

# %%
fig=px.treemap(

category,

path=["product_category_name"],

values="payment_value",

title="Revenue Treemap"

)

fig.show()

# %%
fig=px.bar(

city,

x="customer_city",

y="payment_value",

text_auto=".2s",

title="Top Cities by Revenue"

)

fig.update_layout(

template="plotly_white",

title_x=0.5

)

fig.show()

# %%
city=dashboard.groupby(

"customer_city"

)["payment_value"].sum().sort_values(ascending=False).head(10).reset_index()

# %%
fig=px.pie(

payment,

values="payment_value",

names="payment_type",

title="Revenue by Payment Method"

)

fig.update_layout(

template="plotly_white",

title_x=0.5

)

fig.show()

# %%
payment=dashboard.groupby(

"payment_type"

)["payment_value"].sum().reset_index()

# %%
fig=px.bar(

review,

x="Review",

y="Count",

text_auto=True,

title="Customer Review Distribution"

)

fig.update_layout(

template="plotly_white",

title_x=0.5

)

fig.show()

# %%
review=dashboard["review_score"].value_counts().sort_index().reset_index()

review.columns=[

"Review",

"Count"

]

# %%
fig=px.bar(

category,

x="product_category_name",

y="payment_value",

text_auto=".2s",

title="Top Product Categories"

)

fig.update_layout(

template="plotly_white",

title_x=0.5

)

fig.show()

# %%
category=dashboard.groupby(

"product_category_name"

)["payment_value"].sum().sort_values(ascending=False).head(10).reset_index()

# %%
fig=px.bar(

state,

x="customer_state",

y="payment_value",

text_auto=".2s",

title="Revenue by State"

)

fig.update_layout(

template="plotly_white",

title_x=0.5

)

fig.show()

# %%
state=dashboard.groupby(

"customer_state"

)["payment_value"].sum().reset_index()

state=state.sort_values(

"payment_value",

ascending=False

)

# %%
fig=px.line(

monthly,

x="month",

y="payment_value",

markers=True,

title="Monthly Revenue Trend"

)

fig.update_layout(

template="plotly_white",

title_x=0.5

)

fig.show()

# %%
monthly=dashboard.groupby(

"month"

)["payment_value"].sum().reset_index()

# %%
dashboard["month"]=dashboard[
"order_purchase_timestamp"
].dt.to_period("M").astype(str)

# %%
dashboard["order_purchase_timestamp"]=pd.to_datetime(

dashboard["order_purchase_timestamp"]

)

# %%
dashboard=pd.read_sql("""

SELECT

o.order_purchase_timestamp,

c.customer_state,

c.customer_city,

p.product_category_name,

op.payment_type,

op.payment_value,

r.review_score

FROM orders o

JOIN customers c

ON o.customer_id=c.customer_id

JOIN order_items oi

ON o.order_id=oi.order_id

JOIN products p

ON oi.product_id=p.product_id

JOIN order_payments op

ON o.order_id=op.order_id

LEFT JOIN order_reviews r

ON o.order_id=r.order_id

""",engine)

# %%
USERNAME="postgres"
PASSWORD="password"

HOST="localhost"
PORT="5432"
DATABASE="olist_retail"

engine=create_engine(
f"postgresql+psycopg2://{USERNAME}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}"
)

# %%
USERNAME="postgres"
PASSWORD="password"

HOST="localhost"
PORT="5432"
DATABASE="olist_retail"

engine=create_engine(
f"postgresql+psycopg2://{USERNAME}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}"
)

# %%
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

from sqlalchemy import create_engine

# %%
# # Professional Business Visualizations

# ## Objective

# This notebook develops interactive visualizations for the Retail Sales Intelligence Platform.

# The dashboards created here provide executives with quick insights into:

# - Revenue
# - Customers
# - Products
# - Payments
# - Geography
# - Reviews

# These visualizations will also serve as the basis for the Power BI Dashboard.
